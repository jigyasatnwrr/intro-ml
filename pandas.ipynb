# %% [markdown]
# <a href="https://colab.research.google.com/github/jigyasatnwrr/intro-ml/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **creating pandas Dataframe**

# %%
from sklearn.datasets import fetch_california_housing
cal_dataset = fetch_california_housing()
print(cal_dataset)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
cal_fd = pd.DataFrame(cal_dataset.data, columns=cal_dataset.feature_names)
cal_fd.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
cal_fd.shape
# Out:
# (20640, 8)

# %% [markdown]
# # **importing the data from cvs file to pandas dataframe**

# %%
diabetes_df = pd.read_csv('/diabetes.csv')

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %% [markdown]
# # **loading the data from a excel file to a pandas dataframe**

# %%
pd.read_excel('file path')

# %% [markdown]
# # **exporting a dataframe to csv file**

# %%
cal_fd.to_csv('cal_fd.csv')

# %% [markdown]
# Exporting the pandas dataframe to an excel file:
# df.to_excel("filename')

# %% [markdown]
# # **creating dataframe with random value**

# %%
random_df = pd.DataFrame(np.random.rand(20,10))
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.347081  0.718140  0.758716  0.496203  0.356878  0.599823  0.083228
# 1  0.987796  0.259293  0.690241  0.099103  0.613074  0.961807  0.696365
# 2  0.153451  0.075712  0.458766  0.980984  0.073926  0.364152  0.150200
# 3  0.814371  0.632299  0.220558  0.450885  0.880302  0.543606  0.229961
# 4  0.668796  0.727365  0.957801  0.810768  0.638773  0.559379  0.672105
#
#           7         8         9
# 0  0.470176  0.624345  0.691995
# 1  0.385126  0.320100  0.940037
# 2  0.111589  0.976574  0.734280
# 3  0.124753  0.057160  0.424199
# 4  0.916285  0.506882  0.673379

# %%
random_df.shape
# Out:
# (20, 10)

# %% [markdown]
# # **inspecting dataframe**
